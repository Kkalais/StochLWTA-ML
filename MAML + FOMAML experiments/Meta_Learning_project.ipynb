# %% [markdown]
# ## 8088 -> tf2, 8089 -> pytorch

# %%
import os
os.getcwd()
# Out:
# '/tf/Meta-Learning'

# %%
# %cd MetaLearning-TF2.0
# Out:
# /tf/Meta-Learning/MetaLearning-TF2.0

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# !python models/maml/maml_omniglot.py --algorithm="MAML" --learning_rate=0.001 --load_model=False 
                                    
#!python models/maml/maml_omniglot.py --algorithm="FOMAML" --learning_rate=0.05 --load_model=False 
#                                       --lwta=True --bma=False
# Out:
# 2021-08-26 16:45:17.071270: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-08-26 16:45:21.306830: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-08-26 16:45:21.307903: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-08-26 16:45:21.341292: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:04:00.0 name: Tesla K40c computeCapability: 3.5
# coreClock: 0.745GHz coreCount: 15 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 268.58GiB/s
# 2021-08-26 16:45:21.341908: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:03:00.0 name: Quadro K600 computeCapability: 3.0
# coreClock: 0.8755GHz coreCount: 1 deviceMemorySize: 980.94MiB deviceMemoryBandwidth: 26.55GiB/s
# ...

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

#!python models/maml/maml_omniglot.py --algorithm="MAML" --learning_rate=0.001 --load_model=False 
                                    
# !python models/maml/maml_omniglot.py --algorithm="FOMAML" --learning_rate=0.05 --load_model=False 
#                                       --lwta=True --bma=False
# Out:
# 2021-08-26 17:15:25.290256: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-08-26 17:15:29.540488: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-08-26 17:15:29.541546: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-08-26 17:15:29.573404: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:04:00.0 name: Tesla K40c computeCapability: 3.5
# coreClock: 0.745GHz coreCount: 15 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 268.58GiB/s
# 2021-08-26 17:15:29.574024: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:03:00.0 name: Quadro K600 computeCapability: 3.0
# coreClock: 0.8755GHz coreCount: 1 deviceMemorySize: 980.94MiB deviceMemoryBandwidth: 26.55GiB/s
# ...

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# !python models/maml/maml_miniimagenet.py --algorithm="MAML" --learning_rate=0.001 --load_model=False 
#!python models/maml/maml_miniimagenet.py --algorithm="FOMAML" --learning_rate=0.005 --load_model=False
# Out:
# 2021-08-24 15:17:12.699958: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-08-24 15:17:16.960955: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-08-24 15:17:16.962023: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-08-24 15:17:16.992399: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:04:00.0 name: Tesla K40c computeCapability: 3.5
# coreClock: 0.745GHz coreCount: 15 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 268.58GiB/s
# 2021-08-24 15:17:16.993265: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 1 with properties:
# pciBusID: 0000:03:00.0 name: Quadro K600 computeCapability: 3.0
# coreClock: 0.8755GHz coreCount: 1 deviceMemorySize: 980.94MiB deviceMemoryBandwidth: 26.55GiB/s
# ...
